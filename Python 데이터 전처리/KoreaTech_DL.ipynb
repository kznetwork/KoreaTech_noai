# %% [markdown]
# # 『2과목』 빅데이터 분석 도구

# %% [markdown]
# ## 『2-1』 빅데이터 분석 도구 –소개

# %% [markdown]
# ### Google Colab 명령어

# %%
# OS
# !cat /etc/issue.net
# Out:
# Ubuntu 22.04.4 LTS

# %%
# CPU 사양
# !head /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2200.212
# cache size	: 56320 KB
# physical id	: 0

# %%
# 메모리 사양
# !head -n 3 /proc/meminfo
# Out:
# MemTotal:       13289424 kB
# MemFree:         7668108 kB
# MemAvailable:   11980168 kB

# %%
# !df
# Out:
# Filesystem     1K-blocks     Used Available Use% Mounted on
# overlay        112947452 38771004  74160064  35% /
# tmpfs              65536        0     65536   0% /dev
# shm              5989376        0   5989376   0% /dev/shm
# /dev/root        2019696  1226180    793516  61% /usr/sbin/docker-init
# /dev/sda1       88512476 68268388  20227704  78% /kaggle/input
# tmpfs            6644712       80   6644632   1% /var/colab
# tmpfs            6644712        0   6644712   0% /proc/acpi
# tmpfs            6644712        0   6644712   0% /proc/scsi
# tmpfs            6644712        0   6644712   0% /sys/firmware

# %%
import sys
print(sys.version)
# Out:
# 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %% [markdown]
# ###  기존 접근 방식과 머신 러닝 접근 방식 비교
# ```
# 3*x + 1 계산

# %%
def f (x) :
 return 3*x + 1

x = 10
y = f(x)

print('y:', y)
# Out:
# y: 31

# %%
import tensorflow as tf
import numpy as np

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0])
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0])

model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='sgd', loss='mean_squared_error')

model.fit(xs, ys, epochs=5)

# 수정된 부분
p = model.predict(np.array([10.0]))

print('p:', p)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 17.7430
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 13.9823
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 11.0232
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 8.6946
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 6.8621
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# p: [[22.441847]]

# %% [markdown]
# ### 사칙 연산

# %% [markdown]
# #### 덧셈

# %%
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
#데이터 셋 -X1, X2
X1=tf.placeholder(tf.float32, shape=[None])
X2=tf.placeholder(tf.float32, shape=[None])
y=tf.placeholder(tf.float32, shape=[None])
W1=tf.Variable(tf.random_normal([1]), name="weight1")
W2=tf.Variable(tf.random_normal([1]), name="weight2")
b=tf.Variable(tf.random_normal([1]), name="bias")
#(H(x))
hypothesis=X1*W1+X2*W2+b
#손실함수
cost=tf.reduce_mean(tf.square(hypothesis-y))
#경사하강
optimizer=tf.train.GradientDescentOptimizer(learning_rate=0.01)
#개선
train=optimizer.minimize(cost)
#훈련
sess = tf.Session()
sess.run(tf.global_variables_initializer())
for step in range(5001):
    #sess.run(train)
    _cost, _W1, _W2, _b, _= \
      sess.run([cost, W1, W2, b, train],
               feed_dict={
                   X1: [5,7],
                   X2: [5,7],
                   y: [10,14]
               })
    if step % 500 == 0:
      print(step, _cost, _W1, _W2, _b)
print("덧셈 결과 :", sess.run(hypothesis, feed_dict={X1: [2], X2: [2]}))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 0 191.38678 [2.2663503] [0.82918686] [0.24916257]
# 500 0.00039720483 [1.7087543] [0.27158988] [0.12116613]
# 1000 0.0002329504 [1.7110567] [0.27389112] [0.09278905]
# 1500 0.00013660316 [1.7128195] [0.27565348] [0.07105797]
# 2000 8.01177e-05 [1.7141688] [0.27700385] [0.05441634]
# 2500 4.698839e-05 [1.7152022] [0.27803767] [0.04167205]
# 3000 2.7557266e-05 [1.7159939] [0.27882916] [0.03191246]
# 3500 1.6158543e-05 [1.7166005] [0.27943495] [0.02443854]
# 4000 9.475844e-06 [1.7170656] [0.27989846] [0.01871496]
# 4500 5.558432e-06 [1.717421] [0.28025413] [0.01433199]
# 5000 3.2607518e-06 [1.7176936] [0.28052607] [0.01097547]
# 덧셈 결과 : [4.007415]

# %% [markdown]
# #### 뺄셈

# %%
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
#데이터 셋 -X1, X2
X1=tf.placeholder(tf.float32, shape=[None])
X2=tf.placeholder(tf.float32, shape=[None])
y=tf.placeholder(tf.float32, shape=[None])
W1=tf.Variable(tf.random_normal([1]), name="weight1")
W2=tf.Variable(tf.random_normal([1]), name="weight2")
b=tf.Variable(tf.random_normal([1]), name="bias")
#(H(x))
hypothesis=X1*W1+X2*W2+b
#손실함수
cost=tf.reduce_mean(tf.square(hypothesis-y))
#경사하강
optimizer=tf.train.GradientDescentOptimizer(learning_rate=0.01)
#개선
train=optimizer.minimize(cost)
#훈련
sess = tf.Session()
sess.run(tf.global_variables_initializer())
for step in range(5001):
    #sess.run(train)
    _cost, _W1, _W2, _b, _= \
      sess.run([cost, W1, W2, b, train],
               feed_dict={
                   X1: [5,7],
                   X2: [4,6],
                   y: [1,1]
               })
    if step % 500 == 0:
      print(step, _cost, _W1, _W2, _b)
print("뺄셈 결과 :", sess.run(hypothesis, feed_dict={X1: [4], X2: [2]}))
# Out:
# 0 85.71676 [0.4138707] [0.2949987] [-0.4610717]
# 500 0.026779156 [0.30249125] [-0.14151904] [-0.13593355]
# 1000 0.010475041 [0.38645342] [-0.28577638] [0.09228586]
# 1500 0.004097466 [0.4389658] [-0.37599918] [0.23502132]
# 2000 0.0016027845 [0.47180876] [-0.43242753] [0.32429266]
# 2500 0.00062695076 [0.49234995] [-0.4677197] [0.38012567]
# 3000 0.00024523743 [0.5051971] [-0.48979262] [0.41504532]
# 3500 9.5928306e-05 [0.5132323] [-0.5035979] [0.43688527]
# 4000 3.7523267e-05 [0.5182574] [-0.51223177] [0.4505446]
# 4500 1.4676504e-05 [0.52140003] [-0.5176314] [0.45908785]
# 5000 5.7405136e-06 [0.5233661] [-0.5210092] [0.46443093]
# 뺄셈 결과 : [1.5158769]

# %% [markdown]
# #### 곱셈

# %%
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
#데이터 셋 -X1, X2
X1=tf.placeholder(tf.float32, shape=[None])
X2=tf.placeholder(tf.float32, shape=[None])
y=tf.placeholder(tf.float32, shape=[None])
W1=tf.Variable(tf.random_normal([1]), name="weight1")
W2=tf.Variable(tf.random_normal([1]), name="weight2")
b=tf.Variable(tf.random_normal([1]), name="bias")
#(H(x))
hypothesis=X1*W1+X2*W2+b
#손실함수
cost=tf.reduce_mean(tf.square(hypothesis-y))
#경사하강
optimizer=tf.train.GradientDescentOptimizer(learning_rate=0.01)
#개선
train=optimizer.minimize(cost)
#훈련
sess = tf.Session()
sess.run(tf.global_variables_initializer())
for step in range(5001):
    #sess.run(train)
    _cost, _W1, _W2, _b, _= \
      sess.run([cost, W1, W2, b, train],
               feed_dict={
                   X1: [5,7,2,3,6],
                   X2: [5,7,2,3,6],
                   y: [25,49,4,9,36]
               })
    if step % 500 == 0:
      print(step, _cost, _W1, _W2, _b)
print("곱셈 결과 :", sess.run(hypothesis, feed_dict={X1: [4], X2: [4]}))
# Out:
# 0 986.03644 [2.4116135] [3.108376] [1.7314584]
# 500 8.669229 [3.6764705] [4.373232] [-11.800347]
# 1000 5.917676 [3.9968572] [4.6936193] [-15.217525]
# 1500 5.742189 [4.0777698] [4.774532] [-16.080513]
# 2000 5.73099 [4.0982027] [4.794965] [-16.298452]
# 2500 5.7302856 [4.103363] [4.800125] [-16.353487]
# 3000 5.730231 [4.104666] [4.8014283] [-16.367388]
# 3500 5.7302375 [4.1049953] [4.8017573] [-16.370895]
# 4000 5.7302365 [4.1050744] [4.8018365] [-16.371742]
# 4500 5.7302365 [4.1050744] [4.8018365] [-16.371742]
# 5000 5.7302365 [4.1050744] [4.8018365] [-16.371742]
# 곱셈 결과 : [19.255901]

# %% [markdown]
# #### 나눗셈

# %%
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
#데이터 셋 -X1, X2
X1=tf.placeholder(tf.float32, shape=[None])
X2=tf.placeholder(tf.float32, shape=[None])
y=tf.placeholder(tf.float32, shape=[None])
W1=tf.Variable(tf.random_normal([1]), name="weight1")
W2=tf.Variable(tf.random_normal([1]), name="weight2")
b=tf.Variable(tf.random_normal([1]), name="bias")
#(H(x))
hypothesis=X1*W1+X2*W2+b
#손실함수
cost=tf.reduce_mean(tf.square(hypothesis-y))
#경사하강
optimizer=tf.train.GradientDescentOptimizer(learning_rate=0.01)
#개선
train=optimizer.minimize(cost)
#훈련
sess = tf.Session()
sess.run(tf.global_variables_initializer())
for step in range(5001):
    #sess.run(train)
    _cost, _W1, _W2, _b, _= \
      sess.run([cost, W1, W2, b, train],
               feed_dict={
                   X1: [4,8],
                   X2: [2,4],
                   y: [2,2]
               })
    if step % 500 == 0:
      print(step, _cost, _W1, _W2, _b)
print("나눗셈 결과 :", sess.run(hypothesis, feed_dict={X1: [6], X2: [2]}))
# Out:
# 0 45.938946 [-0.33095807] [1.4999142] [-0.6602367]
# 500 0.09960076 [-0.5463995] [1.3921943] [1.0039762]
# 1000 0.0139387 [-0.6213567] [1.3547152] [1.6273943]
# 1500 0.0019506628 [-0.64939827] [1.3406957] [1.8606107]
# 2000 0.00027298243 [-0.65988934] [1.3354527] [1.947856]
# 2500 3.8205166e-05 [-0.6638141] [1.3334919] [1.9804927]
# 3000 5.3468116e-06 [-0.6652826] [1.3327589] [1.9927022]
# 3500 7.482531e-07 [-0.6658317] [1.3324839] [1.99727]
# 4000 1.047647e-07 [-0.6660386] [1.3323842] [1.9989784]
# 4500 1.46799835e-08 [-0.666114] [1.332343] [1.9996176]
# 5000 2.0807533e-09 [-0.66614896] [1.3323412] [1.999856]
# 나눗셈 결과 : [0.6676445]

# %% [markdown]
# ### 8시간 때의 하루 매출액 구하기

# %%
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

xData=[1,2,3,4,5,6,7]
yData=[25000,55000,75000,110000,128000,155000,180000]

W=tf.Variable(tf.random_uniform([1], -100, 100))
b=tf.Variable(tf.random_uniform([1], -100, 100))

X=tf.placeholder(tf.float32)
Y=tf.placeholder(tf.float32)

H=W*X+b
cost=tf.reduce_mean(tf.square(H-Y))

a=tf.Variable(0.01)
optimizer=tf.train.GradientDescentOptimizer(a)
train=optimizer.minimize(cost)
init=tf.global_variables_initializer()

sess=tf.Session()
sess.run(init)

for i in range(5001):
   sess.run(train, feed_dict={X: xData, Y: yData})
   if i % 500 ==0:
       print(i, sess.run(cost, feed_dict={X: xData, Y: yData}), sess.run(W), sess.run(b))
print(sess.run(H, feed_dict={X: [8]}))
# Out:
# 0 4567259600.0 [10399.743] [2158.0483]
# 500 8689515.0 [25535.2] [1961.6893]
# 1000 8633857.0 [25627.168] [1506.2618]
# 1500 8632678.0 [25640.57] [1439.8954]
# 2000 8632653.0 [25642.523] [1430.2205]
# 2500 8632640.0 [25642.805] [1428.8242]
# 3000 8632657.0 [25642.844] [1428.6343]
# 3500 8632657.0 [25642.848] [1428.6133]
# 4000 8632657.0 [25642.848] [1428.6133]
# 4500 8632657.0 [25642.848] [1428.6133]
# 5000 8632657.0 [25642.848] [1428.6133]
# [206571.39]
