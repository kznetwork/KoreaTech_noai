# %% [markdown]
# ## Set Up

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해

# %% [markdown]
# ## 공식 홈페이지에 안내하는 코드

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # pretrained YOLOv8n model

# Run batched inference on a list of images
results = model(['im1.jpg', 'im2.jpg'])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Class probabilities for classification outputs

# %% [markdown]
# ## 공식 홈페이지에 안내하는 코드 수정

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # pretrained YOLOv8n model

# Define image file path
image_folder = 'C:\\DEV\\KoreaTech\\YOLO\\'

# Define image file names
image_file_1 = 'im1.jpg'
image_file_2 = 'im2.jpg'

# Construct full image file paths
image_path_1 = image_folder + image_file_1
image_path_2 = image_folder + image_file_2

# Run batched inference on a list of images
results = model([image_path_1, image_path_2])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Class probabilities for classification outputs
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 84.1MB/s 0.1s
#
# 0: 640x640 9 persons, 12 cars, 5 buss, 46.7ms
# 1: 640x640 9 cars, 6 buss, 46.7ms
# Speed: 3.8ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# ## 박스형상 으로 확인

# %%
from ultralytics import YOLO
import cv2
# Load a model
model = YOLO('yolov8n.pt')  # pretrained YOLOv8n model
model.predict(source="0", show=True, stream=True, classes=0)  # [0, 3, 5] for multiple classes


# Define image file path
image_folder = 'C:\\DEV\\KoreaTech\\YOLO\\'

# Define image file names
image_file_1 = 'im1.jpg'
image_file_2 = 'im2.jpg'

# Construct full image file paths
image_path_1 = image_folder + image_file_1
image_path_2 = image_folder + image_file_2

# Run batched inference on a list of images
results = model([image_path_1, image_path_2])  # return a list of Results objects
model.predict(source="0", show=True, stream=True, classes=0)

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Class probabilities for classification outputs

    # Print box coordinates
    print("Box coordinates:")
    for box in boxes:
        print(box)

    # Display result with boxes
    result.plot()
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# 0: 640x640 9 persons, 39.1ms
# 1: 640x640 (no detections), 39.1ms
# Speed: 1.9ms preprocess, 39.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Box coordinates:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.6752])
# data: tensor([[339.1403, 212.6867, 353.2872, 246.5004,   0.6752,   0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[346.2137, 229.5935,  14.1469,  33.8137]])
# xywhn: tensor([[0.5770, 0.5769, 0.0236, 0.0850]])
# xyxy: tensor([[339.1403, 212.6867, 353.2872, 246.5004]])
# xyxyn: tensor([[0.5652, 0.5344, 0.5888, 0.6193]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.5861])
# data: tensor([[558.4703, 113.6587, 571.0313, 142.5801,   0.5861,   0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[564.7508, 128.1194,  12.5610,  28.9215]])
# xywhn: tensor([[0.9413, 0.3219, 0.0209, 0.0727]])
# xyxy: tensor([[558.4703, 113.6587, 571.0313, 142.5801]])
# xyxyn: tensor([[0.9308, 0.2856, 0.9517, 0.3582]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.5394])
# data: tensor([[196.5285,   9.3164, 205.3997,  32.0302,   0.5394,   0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[200.9641,  20.6733,   8.8711,  22.7137]])
# xywhn: tensor([[0.3349, 0.0519, 0.0148, 0.0571]])
# xyxy: tensor([[196.5285,   9.3164, 205.3997,  32.0302]])
# xyxyn: tensor([[0.3275, 0.0234, 0.3423, 0.0805]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3839])
# data: tensor([[269.6735,  11.8558, 281.2809,  41.8071,   0.3839,   0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[275.4772,  26.8314,  11.6075,  29.9513]])
# xywhn: tensor([[0.4591, 0.0674, 0.0193, 0.0753]])
# xyxy: tensor([[269.6735,  11.8558, 281.2809,  41.8071]])
# xyxyn: tensor([[0.4495, 0.0298, 0.4688, 0.1050]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3734])
# data: tensor([[151.6979,   0.0000, 160.4447,  20.4159,   0.3734,   0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[156.0713,  10.2079,   8.7468,  20.4159]])
# xywhn: tensor([[0.2601, 0.0256, 0.0146, 0.0513]])
# xyxy: tensor([[151.6979,   0.0000, 160.4447,  20.4159]])
# xyxyn: tensor([[0.2528, 0.0000, 0.2674, 0.0513]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3039])
# data: tensor([[45.3625, 60.7515, 54.5792, 86.5969,  0.3039,  0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[49.9709, 73.6742,  9.2167, 25.8454]])
# xywhn: tensor([[0.0833, 0.1851, 0.0154, 0.0649]])
# xyxy: tensor([[45.3625, 60.7515, 54.5792, 86.5969]])
# xyxyn: tensor([[0.0756, 0.1526, 0.0910, 0.2176]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.2795])
# data: tensor([[245.8231,  16.3536, 254.0670,  36.5780,   0.2795,   0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[249.9450,  26.4658,   8.2439,  20.2244]])
# xywhn: tensor([[0.4166, 0.0665, 0.0137, 0.0508]])
# xyxy: tensor([[245.8231,  16.3536, 254.0670,  36.5780]])
# xyxyn: tensor([[0.4097, 0.0411, 0.4234, 0.0919]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.2706])
# data: tensor([[3.0742e+02, 1.9761e+01, 3.1389e+02, 3.9502e+01, 2.7057e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[310.6548,  29.6317,   6.4737,  19.7406]])
# xywhn: tensor([[0.5178, 0.0745, 0.0108, 0.0496]])
# xyxy: tensor([[307.4180,  19.7613, 313.8917,  39.5020]])
# xyxyn: tensor([[0.5124, 0.0497, 0.5232, 0.0993]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.2699])
# data: tensor([[2.6967e+02, 1.1420e+01, 2.7959e+02, 3.4731e+01, 2.6988e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[274.6338,  23.0753,   9.9207,  23.3110]])
# xywhn: tensor([[0.4577, 0.0580, 0.0165, 0.0586]])
# xyxy: tensor([[269.6735,  11.4198, 279.5941,  34.7308]])
# xyxyn: tensor([[0.4495, 0.0287, 0.4660, 0.0873]])
# Box coordinates:

# %% [markdown]
# # 특정 사물만 인식

# %%
from ultralytics import YOLO
import cv2
# Load a model
model = YOLO('yolov8n.pt')  # pretrained YOLOv8n model
model.predict(source="0", show=True, stream=True, classes=0)  # [0, 3, 5] for multiple classes

# Define image file path
image_folder = 'C:\\DEV\\KoreaTech\\YOLO\\'

# Define image file names
image_file_1 = 'im1.jpg'
image_file_2 = 'im2.jpg'

# Construct full image file paths
image_path_1 = image_folder + image_file_1
image_path_2 = image_folder + image_file_2

# Run batched inference on a list of images
results = model([image_path_1, image_path_2])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Class probabilities for classification outputs

    # Print box coordinates
    print("Box coordinates:")
    for box in boxes:
        print(box)

    # Display result with boxes
    result.plot()
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# 0: 640x640 9 persons, 37.2ms
# 1: 640x640 (no detections), 37.2ms
# Speed: 1.9ms preprocess, 37.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Box coordinates:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.6752])
# data: tensor([[339.1403, 212.6867, 353.2872, 246.5004,   0.6752,   0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[346.2137, 229.5935,  14.1469,  33.8137]])
# xywhn: tensor([[0.5770, 0.5769, 0.0236, 0.0850]])
# xyxy: tensor([[339.1403, 212.6867, 353.2872, 246.5004]])
# xyxyn: tensor([[0.5652, 0.5344, 0.5888, 0.6193]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.5861])
# data: tensor([[558.4703, 113.6587, 571.0313, 142.5801,   0.5861,   0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[564.7508, 128.1194,  12.5610,  28.9215]])
# xywhn: tensor([[0.9413, 0.3219, 0.0209, 0.0727]])
# xyxy: tensor([[558.4703, 113.6587, 571.0313, 142.5801]])
# xyxyn: tensor([[0.9308, 0.2856, 0.9517, 0.3582]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.5394])
# data: tensor([[196.5285,   9.3164, 205.3997,  32.0302,   0.5394,   0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[200.9641,  20.6733,   8.8711,  22.7137]])
# xywhn: tensor([[0.3349, 0.0519, 0.0148, 0.0571]])
# xyxy: tensor([[196.5285,   9.3164, 205.3997,  32.0302]])
# xyxyn: tensor([[0.3275, 0.0234, 0.3423, 0.0805]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3839])
# data: tensor([[269.6735,  11.8558, 281.2809,  41.8071,   0.3839,   0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[275.4772,  26.8314,  11.6075,  29.9513]])
# xywhn: tensor([[0.4591, 0.0674, 0.0193, 0.0753]])
# xyxy: tensor([[269.6735,  11.8558, 281.2809,  41.8071]])
# xyxyn: tensor([[0.4495, 0.0298, 0.4688, 0.1050]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3734])
# data: tensor([[151.6979,   0.0000, 160.4447,  20.4159,   0.3734,   0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[156.0713,  10.2079,   8.7468,  20.4159]])
# xywhn: tensor([[0.2601, 0.0256, 0.0146, 0.0513]])
# xyxy: tensor([[151.6979,   0.0000, 160.4447,  20.4159]])
# xyxyn: tensor([[0.2528, 0.0000, 0.2674, 0.0513]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3039])
# data: tensor([[45.3625, 60.7515, 54.5792, 86.5969,  0.3039,  0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[49.9709, 73.6742,  9.2167, 25.8454]])
# xywhn: tensor([[0.0833, 0.1851, 0.0154, 0.0649]])
# xyxy: tensor([[45.3625, 60.7515, 54.5792, 86.5969]])
# xyxyn: tensor([[0.0756, 0.1526, 0.0910, 0.2176]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.2795])
# data: tensor([[245.8231,  16.3536, 254.0670,  36.5780,   0.2795,   0.0000]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[249.9450,  26.4658,   8.2439,  20.2244]])
# xywhn: tensor([[0.4166, 0.0665, 0.0137, 0.0508]])
# xyxy: tensor([[245.8231,  16.3536, 254.0670,  36.5780]])
# xyxyn: tensor([[0.4097, 0.0411, 0.4234, 0.0919]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.2706])
# data: tensor([[3.0742e+02, 1.9761e+01, 3.1389e+02, 3.9502e+01, 2.7057e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[310.6548,  29.6317,   6.4737,  19.7406]])
# xywhn: tensor([[0.5178, 0.0745, 0.0108, 0.0496]])
# xyxy: tensor([[307.4180,  19.7613, 313.8917,  39.5020]])
# xyxyn: tensor([[0.5124, 0.0497, 0.5232, 0.0993]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.2699])
# data: tensor([[2.6967e+02, 1.1420e+01, 2.7959e+02, 3.4731e+01, 2.6988e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([1, 6])
# xywh: tensor([[274.6338,  23.0753,   9.9207,  23.3110]])
# xywhn: tensor([[0.4577, 0.0580, 0.0165, 0.0586]])
# xyxy: tensor([[269.6735,  11.4198, 279.5941,  34.7308]])
# xyxyn: tensor([[0.4495, 0.0287, 0.4660, 0.0873]])
# Box coordinates:

# %% [markdown]
# ## 코드 개선

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load a pretrained YOLO model
model = YOLO("yolov8n.pt")  # COCO dataset으로 pretrained된 모델을 불러옴

# Define image file path
image_path = "C:\\DEV\\KoreaTech\\YOLO\\im1.jpg"

# Use the model to perform object detection
results = model.predict(image_path)

# Print results for debugging
print(results[0])
print()
print(results[0].boxes)  # 좌상단 좌표, 우하단 좌표, confidence score, class id

# Plot the result
res_plotted = results[0].plot()  # 결과 이미지를 그립니다 (bounding box 등)

# Convert BGR (OpenCV format) to RGB (matplotlib format)
res_plotted_rgb = cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.figure(figsize=(12, 12))
plt.imshow(res_plotted_rgb)
plt.axis('off')  # 축을 숨깁니다
plt.show()
# Out:
# image 1/1 C:\DEV\KoreaTech\YOLO\im1.jpg: 448x640 7 persons, 12 cars, 5 buss, 39.9ms
# Speed: 1.8ms preprocess, 39.9ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[140, 123, 110],
#         [139, 122, 109],
#         [138, 122, 109],
#         ...,
#         [176, 177, 168],
#         [175, 173, 165],
#         [176, 175, 165]],
#
#        [[141, 124, 111],
#         [137, 120, 107],
#         [137, 121, 108],
#         ...,
#         [176, 177, 168],
#         [174, 175, 166],
#         [174, 175, 165]],
#
#        [[142, 125, 112],
#         [140, 123, 110],
#         [141, 125, 112],
#         ...,
#         [174, 175, 166],
#         [170, 173, 164],
#         [171, 174, 165]],
#
#        ...,
#
#        [[158, 149, 135],
#         [156, 145, 131],
#         [156, 143, 129],
#         ...,
#         [ 96,  82,  76],
#         [ 98,  84,  78],
#         [ 98,  84,  78]],
#
#        [[156, 146, 129],
#         [153, 142, 128],
#         [157, 141, 128],
#         ...,
#         [ 98,  82,  75],
#         [ 97,  82,  79],
#         [ 97,  82,  79]],
#
#        [[152, 142, 125],
#         [151, 138, 122],
#         [156, 140, 128],
#         ...,
#         [107,  91,  84],
#         [101,  84,  81],
#         [ 98,  83,  81]]], shape=(398, 600, 3), dtype=uint8)
# orig_shape: (398, 600)
# path: 'C:\\DEV\\KoreaTech\\YOLO\\im1.jpg'
# probs: None
# save_dir: 'C:\\DEV\\runs\\detect\\predict'
# semantic_mask: None
# speed: {'preprocess': 1.7613999989407603, 'inference': 39.91250000035507, 'postprocess': 0.6185000002005836}
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([5., 5., 2., 5., 2., 2., 2., 2., 5., 2., 5., 2., 2., 2., 2., 2., 0., 2., 0., 0., 0., 0., 0., 0.])
# conf: tensor([0.9125, 0.9104, 0.9041, 0.8886, 0.8544, 0.8503, 0.8489, 0.8313, 0.8044, 0.8037, 0.7580, 0.7577, 0.7156, 0.7016, 0.6957, 0.6929, 0.6777, 0.5686, 0.5617, 0.4980, 0.3372, 0.2706, 0.2682, 0.2640])
# data: tensor([[2.7771e+02, 2.4477e+02, 4.0485e+02, 3.7454e+02, 9.1249e-01, 5.0000e+00],
#         [2.9606e+02, 3.6079e+01, 4.3717e+02, 1.4564e+02, 9.1038e-01, 5.0000e+00],
#         [4.5401e+02, 2.2536e+02, 5.3077e+02, 2.7912e+02, 9.0406e-01, 2.0000e+00],
#         [1.6353e+02, 1.2270e+02, 3.0576e+02, 2.7415e+02, 8.8858e-01, 5.0000e+00],
#         [3.8670e+02, 1.6932e+02, 4.5891e+02, 2.1936e+02, 8.5443e-01, 2.0000e+00],
#         [4.3916e+02, 1.5113e+02, 5.1117e+02, 1.9479e+02, 8.5031e-01, 2.0000e+00],
#         [4.9201e+02, 2.0532e+02, 5.7139e+02, 2.5809e+02, 8.4892e-01, 2.0000e+00],
#         [3.2387e+02, 1.2227e+02, 3.7649e+02, 1.5881e+02, 8.3134e-01, 2.0000e+00],
#         [1.3672e-01, 1.4588e+02, 7.6686e+01, 2.8870e+02, 8.0444e-01, 5.0000e+00],
#         [2.6116e+02, 8.0598e+01, 3.1969e+02, 1.1692e+02, 8.0371e-01, 2.0000e+00],
#         [9.2181e+01, 5.4257e+01, 1.9500e+02, 1.6411e+02, 7.5796e-01, 5.0000e+00],
#         [1.6808e+02, 3.4139e+02, 2.4817e+02, 3.9800e+02, 7.5767e-01, 2.0000e+00],
#         [5.6761e+02, 3.0518e+02, 5.9984e+02, 3.5467e+02, 7.1558e-01, 2.0000e+00],
#         [1.0673e+02, 2.7450e+02, 1.8355e+02, 3.5472e+02, 7.0155e-01, 2.0000e+00],
#         [3.6789e-02, 1.1326e+02, 4.5157e+01, 1.7096e+02, 6.9573e-01, 2.0000e+00],
#         [2.2069e+02, 8.8292e+01, 2.7630e+02, 1.2078e+02, 6.9287e-01, 2.0000e+00],
#         [3.3914e+02, 2.1270e+02, 3.5329e+02, 2.4650e+02, 6.7768e-01, 0.0000e+00],
#         [7.9355e+01, 2.1785e+02, 1.4842e+02, 2.8324e+02, 5.6862e-01, 2.0000e+00],
#         [5.5845e+02, 1.1368e+02, 5.7104e+02, 1.4259e+02, 5.6168e-01, 0.0000e+00],
#         [1.9634e+02, 9.0032e+00, 2.0562e+02, 3.1984e+01, 4.9802e-01, 0.0000e+00],
#         [2.6971e+02, 1.2014e+01, 2.8126e+02, 4.1931e+01, 3.3723e-01, 0.0000e+00],
#         [1.5186e+02, 0.0000e+00, 1.6030e+02, 2.0488e+01, 2.7058e-01, 0.0000e+00],
#         [4.5400e+01, 6.0813e+01, 5.4507e+01, 8.6602e+01, 2.6819e-01, 0.0000e+00],
#         [3.0741e+02, 1.9769e+01, 3.1387e+02, 3.9569e+01, 2.6396e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (398, 600)
# shape: torch.Size([24, 6])
# xywh: tensor([[341.2824, 309.6573, 127.1447, 129.7734],
#         [366.6178,  90.8618, 141.1134, 109.5652],
#         [492.3874, 252.2420,  76.7589,  53.7608],
#         [234.6421, 198.4269, 142.2312, 151.4489],
#         [422.8019, 194.3407,  72.2112,  50.0468],
#         [475.1639, 172.9630,  72.0095,  43.6607],
#         [531.6983, 231.7049,  79.3845,  52.7621],
#         [350.1839, 140.5418,  52.6186,  36.5366],
#         [ 38.4112, 217.2906,  76.5490, 142.8217],
#         [290.4225,  98.7576,  58.5275,  36.3182],
#         [143.5916, 109.1844, 102.8207, 109.8546],
#         [208.1237, 369.6936,  80.0877,  56.6128],
#         [583.7284, 329.9228,  32.2322,  49.4886],
#         [145.1415, 314.6109,  76.8131,  80.2157],
#         [ 22.5969, 142.1061,  45.1201,  57.7018],
#         [248.4923, 104.5339,  55.6085,  32.4837],
#         [346.2151, 229.6032,  14.1493,  33.8019],
#         [113.8888, 250.5452,  69.0680,  65.3904],
#         [564.7480, 128.1316,  12.5933,  28.9097],
#         [200.9774,  20.4934,   9.2786,  22.9803],
#         [275.4822,  26.9724,  11.5529,  29.9162],
#         [156.0806,  10.2442,   8.4425,  20.4885],
#         [ 49.9536,  73.7073,   9.1069,  25.7891],
#         [310.6384,  29.6689,   6.4595,  19.7994]])
# xywhn: tensor([[0.5688, 0.7780, 0.2119, 0.3261],
#         [0.6110, 0.2283, 0.2352, 0.2753],
#         [0.8206, 0.6338, 0.1279, 0.1351],
#         [0.3911, 0.4986, 0.2371, 0.3805],
#         [0.7047, 0.4883, 0.1204, 0.1257],
#         [0.7919, 0.4346, 0.1200, 0.1097],
#         [0.8862, 0.5822, 0.1323, 0.1326],
#         [0.5836, 0.3531, 0.0877, 0.0918],
#         [0.0640, 0.5460, 0.1276, 0.3588],
#         [0.4840, 0.2481, 0.0975, 0.0913],
#         [0.2393, 0.2743, 0.1714, 0.2760],
#         [0.3469, 0.9289, 0.1335, 0.1422],
#         [0.9729, 0.8290, 0.0537, 0.1243],
#         [0.2419, 0.7905, 0.1280, 0.2015],
#         [0.0377, 0.3571, 0.0752, 0.1450],
#         [0.4142, 0.2626, 0.0927, 0.0816],
#         [0.5770, 0.5769, 0.0236, 0.0849],
#         [0.1898, 0.6295, 0.1151, 0.1643],
#         [0.9412, 0.3219, 0.0210, 0.0726],
#         [0.3350, 0.0515, 0.0155, 0.0577],
#         [0.4591, 0.0678, 0.0193, 0.0752],
#         [0.2601, 0.0257, 0.0141, 0.0515],
#         [0.0833, 0.1852, 0.0152, 0.0648],
#         [0.5177, 0.0745, 0.0108, 0.0497]])
# xyxy: tensor([[2.7771e+02, 2.4477e+02, 4.0485e+02, 3.7454e+02],
#         [2.9606e+02, 3.6079e+01, 4.3717e+02, 1.4564e+02],
#         [4.5401e+02, 2.2536e+02, 5.3077e+02, 2.7912e+02],
#         [1.6353e+02, 1.2270e+02, 3.0576e+02, 2.7415e+02],
#         [3.8670e+02, 1.6932e+02, 4.5891e+02, 2.1936e+02],
#         [4.3916e+02, 1.5113e+02, 5.1117e+02, 1.9479e+02],
#         [4.9201e+02, 2.0532e+02, 5.7139e+02, 2.5809e+02],
#         [3.2387e+02, 1.2227e+02, 3.7649e+02, 1.5881e+02],
#         [1.3672e-01, 1.4588e+02, 7.6686e+01, 2.8870e+02],
#         [2.6116e+02, 8.0598e+01, 3.1969e+02, 1.1692e+02],
#         [9.2181e+01, 5.4257e+01, 1.9500e+02, 1.6411e+02],
#         [1.6808e+02, 3.4139e+02, 2.4817e+02, 3.9800e+02],
#         [5.6761e+02, 3.0518e+02, 5.9984e+02, 3.5467e+02],
#         [1.0673e+02, 2.7450e+02, 1.8355e+02, 3.5472e+02],
#         [3.6789e-02, 1.1326e+02, 4.5157e+01, 1.7096e+02],
#         [2.2069e+02, 8.8292e+01, 2.7630e+02, 1.2078e+02],
#         [3.3914e+02, 2.1270e+02, 3.5329e+02, 2.4650e+02],
#         [7.9355e+01, 2.1785e+02, 1.4842e+02, 2.8324e+02],
#         [5.5845e+02, 1.1368e+02, 5.7104e+02, 1.4259e+02],
#         [1.9634e+02, 9.0032e+00, 2.0562e+02, 3.1984e+01],
#         [2.6971e+02, 1.2014e+01, 2.8126e+02, 4.1931e+01],
#         [1.5186e+02, 0.0000e+00, 1.6030e+02, 2.0488e+01],
#         [4.5400e+01, 6.0813e+01, 5.4507e+01, 8.6602e+01],
#         [3.0741e+02, 1.9769e+01, 3.1387e+02, 3.9569e+01]])
# xyxyn: tensor([[4.6285e-01, 6.1500e-01, 6.7476e-01, 9.4107e-01],
#         [4.9344e-01, 9.0651e-02, 7.2862e-01, 3.6594e-01],
#         [7.5668e-01, 5.6624e-01, 8.8461e-01, 7.0131e-01],
#         [2.7254e-01, 3.0830e-01, 5.0960e-01, 6.8882e-01],
#         [6.4449e-01, 4.2542e-01, 7.6485e-01, 5.5117e-01],
#         [7.3193e-01, 3.7973e-01, 8.5195e-01, 4.8943e-01],
#         [8.2001e-01, 5.1589e-01, 9.5232e-01, 6.4846e-01],
#         [5.3979e-01, 3.0722e-01, 6.2749e-01, 3.9902e-01],
#         [2.2787e-04, 3.6653e-01, 1.2781e-01, 7.2538e-01],
#         [4.3526e-01, 2.0251e-01, 5.3281e-01, 2.9376e-01],
#         [1.5364e-01, 1.3632e-01, 3.2500e-01, 4.1234e-01],
#         [2.8013e-01, 8.5776e-01, 4.1361e-01, 1.0000e+00],
#         [9.4602e-01, 7.6678e-01, 9.9974e-01, 8.9112e-01],
#         [1.7789e-01, 6.8971e-01, 3.0591e-01, 8.9125e-01],
#         [6.1315e-05, 2.8456e-01, 7.5262e-02, 4.2954e-01],
#         [3.6781e-01, 2.2184e-01, 4.6049e-01, 3.0346e-01],
#         [5.6523e-01, 5.3443e-01, 5.8882e-01, 6.1936e-01],
#         [1.3226e-01, 5.4736e-01, 2.4737e-01, 7.1166e-01],
#         [9.3075e-01, 2.8562e-01, 9.5174e-01, 3.5826e-01],
#         [3.2723e-01, 2.2621e-02, 3.4269e-01, 8.0361e-02],
#         [4.4951e-01, 3.0187e-02, 4.6876e-01, 1.0535e-01],
#         [2.5310e-01, 0.0000e+00, 2.6717e-01, 5.1479e-02],
#         [7.5667e-02, 1.5280e-01, 9.0845e-02, 2.1759e-01],
#         [5.1235e-01, 4.9671e-02, 5.2311e-01, 9.9419e-02]])

# %% [markdown]
# ## YOLOv8의 예측 결과를 그림 위에 "탐지한 객체 수"를 노란색 글씨로 표시

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# 1. Load pretrained YOLO model
model = YOLO("yolov8n.pt")

# 2. Load image
image_path = "C:\\DEV\\KoreaTech\\YOLO\\im1.jpg"

# 3. Object detection
results = model.predict(image_path)
result = results[0]
boxes = result.boxes

# 4. Count detected objects
num_objects = len(boxes)

# 5. Draw results on image
res_plotted = result.plot()  # OpenCV 이미지 (BGR)
text = f"Detected objects: {num_objects}"

# 6. Put yellow text on image (좌상단에 표시)
cv2.putText(
    res_plotted,                     # 이미지
    text,                            # 출력할 텍스트
    (30, 50),                        # 텍스트 위치 (x, y)
    cv2.FONT_HERSHEY_SIMPLEX,       # 폰트
    1.3,                             # 폰트 크기 (13pt 정도에 해당)
    (0, 255, 255),                   # 노란색 (BGR)
    2,                               # 두께
    cv2.LINE_AA                      # 안티앨리어싱
)

# 7. Convert BGR to RGB for matplotlib
res_plotted_rgb = cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB)

# 8. Show the image
plt.figure(figsize=(12, 12))
plt.imshow(res_plotted_rgb)
plt.axis('off')
plt.show()
# Out:
# image 1/1 C:\DEV\KoreaTech\YOLO\im1.jpg: 448x640 7 persons, 12 cars, 5 buss, 102.0ms
# Speed: 2.9ms preprocess, 102.0ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)

# %% [markdown]
# ## YOLOv8 커스텀 데이터 학습하기

# %%
from ultralytics import YOLO
import cv2
# Load a model
model = YOLO('C:\\DEV\\YOLOv8Pro\\runs\\detect\\train\\weights\\best.pt')  # pretrained YOLOv8n model

model.predict(source="0", show=True, stream=True, classes=0)  # [0, 3, 5] for multiple classes


# Define image file path
image_folder = 'C:\\DEV\\YOLOv8Pro\\images\\'

# Define image file names
image_file_1 = 'camera_p_05.jpg'
image_file_2 = 'camera_p_05.jpg'

# Construct full image file paths
image_path_1 = image_folder + image_file_1
image_path_2 = image_folder + image_file_2

# Run batched inference on a list of images
results = model([image_path_1, image_path_2])  # return a list of Results objects
model.predict(source="0", show=True, stream=True, classes=0)

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Class probabilities for classification outputs

    # Print box coordinates
    print("Box coordinates:")
    for box in boxes:
        print(box)

    # Display result with boxes
    result.plot()
    cv2.waitKey(0)
    cv2.destroyAllWindows()

plt.show()
# Out:
# 0: 448x640 10 p_cameras, 60.3ms
# 1: 448x640 10 p_cameras, 60.3ms
# Speed: 1.8ms preprocess, 60.3ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
# Box coordinates:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8046])
# data: tensor([[393.3882, 103.6898, 490.5189, 154.5629,   0.8046,   0.0000]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[441.9535, 129.1263,  97.1307,  50.8731]])
# xywhn: tensor([[0.4316, 0.1896, 0.0949, 0.0747]])
# xyxy: tensor([[393.3882, 103.6898, 490.5189, 154.5629]])
# xyxyn: tensor([[0.3842, 0.1523, 0.4790, 0.2270]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7902])
# data: tensor([[444.1030,  60.9305, 477.1048,  93.4234,   0.7902,   0.0000]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[460.6039,  77.1770,  33.0018,  32.4928]])
# xywhn: tensor([[0.4498, 0.1133, 0.0322, 0.0477]])
# xyxy: tensor([[444.1030,  60.9305, 477.1048,  93.4234]])
# xyxyn: tensor([[0.4337, 0.0895, 0.4659, 0.1372]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7746])
# data: tensor([[403.0518,  60.3994, 438.2021,  93.9319,   0.7746,   0.0000]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[420.6269,  77.1656,  35.1503,  33.5325]])
# xywhn: tensor([[0.4108, 0.1133, 0.0343, 0.0492]])
# xyxy: tensor([[403.0518,  60.3994, 438.2021,  93.9319]])
# xyxyn: tensor([[0.3936, 0.0887, 0.4279, 0.1379]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.5753])
# data: tensor([[368.9534,  44.0646, 492.4266, 154.6407,   0.5753,   0.0000]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[430.6900,  99.3527, 123.4731, 110.5761]])
# xywhn: tensor([[0.4206, 0.1459, 0.1206, 0.1624]])
# xyxy: tensor([[368.9534,  44.0646, 492.4266, 154.6407]])
# xyxyn: tensor([[0.3603, 0.0647, 0.4809, 0.2271]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.4712])
# data: tensor([[3.9650e+02, 1.0454e+02, 4.7879e+02, 1.4545e+02, 4.7120e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[437.6445, 124.9958,  82.2963,  40.9148]])
# xywhn: tensor([[0.4274, 0.1835, 0.0804, 0.0601]])
# xyxy: tensor([[396.4964, 104.5384, 478.7927, 145.4532]])
# xyxyn: tensor([[0.3872, 0.1535, 0.4676, 0.2136]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.4612])
# data: tensor([[4.4386e+02, 5.5925e+01, 4.8318e+02, 9.5610e+01, 4.6121e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[463.5218,  75.7674,  39.3160,  39.6844]])
# xywhn: tensor([[0.4527, 0.1113, 0.0384, 0.0583]])
# xyxy: tensor([[443.8638,  55.9252, 483.1798,  95.6096]])
# xyxyn: tensor([[0.4335, 0.0821, 0.4719, 0.1404]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3997])
# data: tensor([[3.9401e+02, 1.0510e+02, 4.4351e+02, 1.5130e+02, 3.9972e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[418.7618, 128.1994,  49.4992,  46.1952]])
# xywhn: tensor([[0.4089, 0.1883, 0.0483, 0.0678]])
# xyxy: tensor([[394.0122, 105.1018, 443.5114, 151.2970]])
# xyxyn: tensor([[0.3848, 0.1543, 0.4331, 0.2222]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3893])
# data: tensor([[4.4175e+02, 5.2087e+01, 4.9028e+02, 1.4871e+02, 3.8933e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[466.0129, 100.3982,  48.5269,  96.6215]])
# xywhn: tensor([[0.4551, 0.1474, 0.0474, 0.1419]])
# xyxy: tensor([[441.7494,  52.0875, 490.2764, 148.7089]])
# xyxyn: tensor([[0.4314, 0.0765, 0.4788, 0.2184]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3479])
# data: tensor([[3.9258e+02, 5.6368e+01, 4.4253e+02, 1.5200e+02, 3.4792e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[417.5566, 104.1836,  49.9532,  95.6305]])
# xywhn: tensor([[0.4078, 0.1530, 0.0488, 0.1404]])
# xyxy: tensor([[392.5800,  56.3683, 442.5332, 151.9989]])
# xyxyn: tensor([[0.3834, 0.0828, 0.4322, 0.2232]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3284])
# data: tensor([[3.6494e+02, 2.1966e+02, 6.5909e+02, 6.5545e+02, 3.2842e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[512.0139, 437.5529, 294.1518, 435.7918]])
# xywhn: tensor([[0.5000, 0.6425, 0.2873, 0.6399]])
# xyxy: tensor([[364.9380, 219.6570, 659.0897, 655.4489]])
# xyxyn: tensor([[0.3564, 0.3226, 0.6436, 0.9625]])
# Box coordinates:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8046])
# data: tensor([[393.3882, 103.6898, 490.5189, 154.5629,   0.8046,   0.0000]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[441.9535, 129.1263,  97.1307,  50.8731]])
# xywhn: tensor([[0.4316, 0.1896, 0.0949, 0.0747]])
# xyxy: tensor([[393.3882, 103.6898, 490.5189, 154.5629]])
# xyxyn: tensor([[0.3842, 0.1523, 0.4790, 0.2270]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7902])
# data: tensor([[444.1030,  60.9305, 477.1048,  93.4234,   0.7902,   0.0000]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[460.6039,  77.1770,  33.0018,  32.4928]])
# xywhn: tensor([[0.4498, 0.1133, 0.0322, 0.0477]])
# xyxy: tensor([[444.1030,  60.9305, 477.1048,  93.4234]])
# xyxyn: tensor([[0.4337, 0.0895, 0.4659, 0.1372]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7746])
# data: tensor([[403.0518,  60.3994, 438.2021,  93.9319,   0.7746,   0.0000]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[420.6269,  77.1656,  35.1503,  33.5325]])
# xywhn: tensor([[0.4108, 0.1133, 0.0343, 0.0492]])
# xyxy: tensor([[403.0518,  60.3994, 438.2021,  93.9319]])
# xyxyn: tensor([[0.3936, 0.0887, 0.4279, 0.1379]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.5753])
# data: tensor([[368.9534,  44.0646, 492.4266, 154.6407,   0.5753,   0.0000]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[430.6900,  99.3527, 123.4731, 110.5761]])
# xywhn: tensor([[0.4206, 0.1459, 0.1206, 0.1624]])
# xyxy: tensor([[368.9534,  44.0646, 492.4266, 154.6407]])
# xyxyn: tensor([[0.3603, 0.0647, 0.4809, 0.2271]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.4712])
# data: tensor([[3.9650e+02, 1.0454e+02, 4.7879e+02, 1.4545e+02, 4.7120e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[437.6445, 124.9958,  82.2963,  40.9148]])
# xywhn: tensor([[0.4274, 0.1835, 0.0804, 0.0601]])
# xyxy: tensor([[396.4964, 104.5384, 478.7927, 145.4532]])
# xyxyn: tensor([[0.3872, 0.1535, 0.4676, 0.2136]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.4612])
# data: tensor([[4.4386e+02, 5.5925e+01, 4.8318e+02, 9.5610e+01, 4.6121e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[463.5218,  75.7674,  39.3160,  39.6844]])
# xywhn: tensor([[0.4527, 0.1113, 0.0384, 0.0583]])
# xyxy: tensor([[443.8638,  55.9252, 483.1798,  95.6096]])
# xyxyn: tensor([[0.4335, 0.0821, 0.4719, 0.1404]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3997])
# data: tensor([[3.9401e+02, 1.0510e+02, 4.4351e+02, 1.5130e+02, 3.9972e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[418.7618, 128.1994,  49.4992,  46.1952]])
# xywhn: tensor([[0.4089, 0.1883, 0.0483, 0.0678]])
# xyxy: tensor([[394.0122, 105.1018, 443.5114, 151.2970]])
# xyxyn: tensor([[0.3848, 0.1543, 0.4331, 0.2222]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3893])
# data: tensor([[4.4175e+02, 5.2087e+01, 4.9028e+02, 1.4871e+02, 3.8933e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[466.0129, 100.3982,  48.5269,  96.6215]])
# xywhn: tensor([[0.4551, 0.1474, 0.0474, 0.1419]])
# xyxy: tensor([[441.7494,  52.0875, 490.2764, 148.7089]])
# xyxyn: tensor([[0.4314, 0.0765, 0.4788, 0.2184]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3479])
# data: tensor([[3.9258e+02, 5.6368e+01, 4.4253e+02, 1.5200e+02, 3.4792e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[417.5566, 104.1836,  49.9532,  95.6305]])
# xywhn: tensor([[0.4078, 0.1530, 0.0488, 0.1404]])
# xyxy: tensor([[392.5800,  56.3683, 442.5332, 151.9989]])
# xyxyn: tensor([[0.3834, 0.0828, 0.4322, 0.2232]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.3284])
# data: tensor([[3.6494e+02, 2.1966e+02, 6.5909e+02, 6.5545e+02, 3.2842e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (681, 1024)
# shape: torch.Size([1, 6])
# xywh: tensor([[512.0139, 437.5529, 294.1518, 435.7918]])
# xywhn: tensor([[0.5000, 0.6425, 0.2873, 0.6399]])
# xyxy: tensor([[364.9380, 219.6570, 659.0897, 655.4489]])
# xyxyn: tensor([[0.3564, 0.3226, 0.6436, 0.9625]])

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# 모델 로드
model = YOLO('C:\\DEV\\YOLOv8Pro\\runs\\detect\\train\\weights\\best.pt')

# 배치 추론
results = model(['C:\\DEV\\YOLOv8Pro\\images\\camera_p_05.jpg',
                 'C:\\DEV\\YOLOv8Pro\\images\\camera_p_05.jpg'])

# 결과 처리
for i, result in enumerate(results):
    annotated = result.plot()                                   # BGR 배열
    annotated_rgb = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)  # BGR → RGB

    plt.figure(figsize=(10, 8))
    plt.imshow(annotated_rgb)
    plt.axis('off')
    plt.title(f'result_{i}')
    plt.show()
# Out:
# 0: 448x640 10 p_cameras, 61.2ms
# 1: 448x640 10 p_cameras, 61.2ms
# Speed: 12.5ms preprocess, 61.2ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
