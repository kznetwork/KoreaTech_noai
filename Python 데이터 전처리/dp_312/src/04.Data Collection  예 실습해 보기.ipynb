}],"_id":"643e6299a10d3006853cc04c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"20c06c52-62ff-11f1-a74e-85a55f4989d9","@provider":"lambda","@lastModifiedAt":[2026,6,8,5,58,53,135000000]}
# </script>
# <script>
# window["ELECTION-DATA"] = window["ELECTION-DATA"] || {};
# window["ELECTION-DATA"] = {"noElectionData": true}
# </script>
# <script>!function(){var e=Math.random()<1;const n={"s.pstatic.net":"s.naver.net","pm.pstatic.net":"pm.naver.net","mm.pstatic.net":"mm.naver.net","mml.pstatic.net":"mml.naver.net"};window.nmain=window.nmain||{},window.nmain&&(window.nmain.cdnFallbackLogQueue=[]);function t(e){try{if(!window.nmain)return;if(Math.random()>=.01)return;var n=new Error(e);window.nmain.sendInfo?window.nmain.sendInfo(n):window.nmain.cdnFallbackLogQueue&&window.nmain.cdnFallbackLogQueue.push(n)}catch(e){}}function r(e,t){const r=new URL(e),a=n[r.hostname];if(!a)return e;if(e.includes(".cdnfallback."))return e;r.hostname=a;const c=new RegExp(`\\.(${t})$`,"i");return r.pathname=r.pathname.replace(c,".cdnfallback.$1"),r.toString()}window.addEventListener("error",a=>{const{target:c}=a;if(e)if(c.dataset&&"done"===c.dataset.cdnFallbackAttempt)c instanceof HTMLImageElement?t("[CDN Fallback] fallback img resource load failed: "+c.src):c instanceof HTMLLinkElement?t("[CDN Fallback] fallback css resource load failed: "+c.href):c instanceof HTMLScriptElement&&t("[CDN Fallback] fallback js resource load failed: "+c.src);else if(c instanceof HTMLImageElement){var o=c.src;(function(e,t){if(!e.src)return!1;const r=new URL(e.src),a=n[r.hostname];if(!a)return!1;t.stopImmediatePropagation(),t.preventDefault();var c=r.hostname;if(r.hostname=a,e.src=r.toString(),e.srcset&&(e.srcset=e.srcset.split("//"+c).join("//"+a)),e.parentElement&&e.parentElement instanceof HTMLPictureElement)for(var o=e.parentElement.querySelectorAll("source"),i=0;i<o.length;i++){var s=o[i];s.srcset&&Object.keys(n).forEach(function(e){s.srcset=s.srcset.split("//"+e).join("//"+n[e])})}return e.dataset.cdnFallbackAttempt="done",!0})(c,a)&&t("[CDN Fallback] origin img resource load failed: "+o)}else c instanceof HTMLLinkElement?function(e){if(!e.href||"done"===e.dataset.cdnFallbackAttempt)return!1;const n=r(e.href,"css");if(n!==e.href){const t=document.createElement("link");return t.rel="stylesheet",t.href=n,t.dataset.cdnFallbackAttempt="done",e.onerror&&(t.onerror=e.onerror),e.type&&(t.type=e.type),e.media&&(t.media=e.media),e.parentNode&&e.parentNode.insertBefore(t,e.nextSibling),!0}return!1}(c)&&t("[CDN Fallback] origin css resource load failed: "+c.href):c instanceof HTMLScriptElement&&function(e){if(!e.src||"done"===e.dataset.cdnFallbackAttempt)return!1;const n=r(e.src,"js");if(n!==e.src){const t=document.createElement("script");return t.src=n,t.crossOrigin=e.crossOrigin,t.async=e.async,t.defer=e.defer,t.dataset.cdnFallbackAttempt="done",e.onerror&&(t.onerror=e.onerror),e.type&&(t.type=e.type),e.parentNode&&e.parentNode.insertBefore(t,e.nextSibling),!0}return!1}(c)&&t("[CDN Fallback] origin js resource load failed: "+c.src)},{capture:!0})}()</script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.9d57c570.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/preload.20fd9b94.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/search.c986c99d.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/main.b0b14d22.js?o=www"></script><link href="https://pm.pstatic.net/resources/css/main.09f14cf0.css" rel="stylesheet"/></head> <body> <div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div> <script data-gfp-banner-size="830x130" data-gfp-banner-type="full" id="ad-timeboard-response" type="text/plain">{"payload":{"requestId":"29eb6d5f5ebf4cbebcd64129de386e70","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{"ac ...
# </script> <div id="wrap"> <div id="whale-banner"></div> <div id="header" role="banner"> <div class="header_inner" id="topSearchWrap"> <div class="search_special_bg" id="special-logo"></div> <div class="ad_area" id="timeboard-ex" style="width:1280px"> </div> <div class="search_area" id="search_area" style="border-color:#fff"> <div class="search_group"> <div class="search_group_inner" id="search"> <h1 class="search_logo" id="special-input-logo"></h1> <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search"> <fieldset> <legend class="blind">검색</legend> <input name="where" type="hidden" value="nexearch"/> <input id="sm" name="sm" type="hidden" value="top_hty"/> <input id="fbm" name="fbm" type="hidden" value="0"/> <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/> <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/> <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/> <input id="ie" name="ie" type="hidden" value="utf8"/> <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/> <input disabled="disabled" id="os" name="os" type="hidden" value=""/> <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/> <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/> <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/> <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/> <div class="search_input_box"> <input aria-activedescendant="" aria-autocomplete="list" aria-controls="" aria-expanded="false" aria-haspopup="listbox" aria-owns="autoFrame" autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." role="combobox" title="검색어를 입력해 주세요." type="search"/> </div> <button class="btn_search" id="search-btn" onclick='window.ntm.push({event:"nclick",el:this,click_area:"sch.action"})' style="display:none" type="submit"> <span class="ico_btn_search_svg"> <svg id="search-btn-svg" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"></path> </svg> </span> <span class="blind">검색</span> </button> <button class="btn_ai_search type_effect" id="search-ai-tab-button" type="submit"> <span class="ai_effect_symbol" id="search-ai-tab-button-inner"></span> <span class="blind">AI 검색</span> </button> </fieldset> </form> <div class="search_box" id="search-box" style="display:none"> <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button"> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"></div> </div> </div> </div> <div id="search-right"></div> <div aria-label="주요 서비스" class="shortcut_area" id="shortcutArea" role="navigation"></div> <div class="menu_area" id="topAsideArea"></div> <div class="pay_area" id="topPayArea"></div> <div class="talk_area" id="topTalkArea"></div> <div class="notify_area" id="topNotiArea"></div> <div class="shopping_area" id="topShoppingArea"></div> </div> </div> <div id="container" role="main"> <div class="ad_premium_area" id="ad_premium_area" style="min-width:1920px"> </div> <div id="root"></div> </div> <div id="footer" role="contentinfo"></div> </div> <script> window['EAGER-DATA'] = windo ...
#         window['EAGER-DATA']['GV'] = {
#             svt: '20260608150020',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),i=document.getElementById("search-btn-svg");if(!t)return e&&e.removeAttribute("style"),void(i&&i.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),i&&i.setAttribute("class","ico_btn_search type_color"),i&&i.setAttribute("style","fill: "+t)}var e=function(){if(!window["EAGER-DATA"].GV.isBirthday)return null;const t=window["EAGER-DATA"].GV.svt;return/^[0-9]{4}(06|07|08)/.test(t)?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20250825_0/upload_1756126598310vru58.png",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20250825_0/upload_175612662068439LsF.png",textColor:"#0E9FF2"},input:{showSearchLogo:!0,color:"#0E9FF2",logoImage:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.summer.n.png"}}:/^[0-9]{4}(09|10|11)/.test(t)?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20250828_0/pc_birth_9_10_11.gif",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20250918_0/pc_birth_9_10_11_dark.gif",textColor:"#FF6700"},input:{showSearchLogo:!0,color:"#FF6700",logoImage:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.fall.n.png"}}:/^[0-9]{4}(12|01|02)/.test(t)?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20251209_0/pc_birth_12_1_2.gif",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20251209_0/pc_birth_12_1_2_dark.gif",textColor:"#895bd2"},input:{showSearchLogo:!0,color:"#895bd2",logoImage:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.winter.n.png"}}:/^[0-9]{4}(03|04|05)/.test(t)?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/spring.gif",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/spring.dark.gif",textColor:"#f86391"},input:{showSearchLogo:!0,color:"#f86391",logoImage:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.spring.n.png"}}:null}(),i=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!(e||i&&i.items&&i.items.length>0!=!1))return void t();const o=!e&&i.items[0]?.content?.logo?.isWedding?{logo:{image:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.wedding.gif",imageDark:"https://s.pstatic.net/static/www/mobile/edit/20260406_0/pc.wedding.dark.gif",textColor:"#0091F3",textColorDark:"#3AAFFE",isWedding:!0},input:{color:"#3AAFFE"}}:null;var s=function(){if(e){const t=e;return Object.assign(t.logo,{alt:"생일 축하 합니다.",top:0,left:0,clickAreaList:[{left:0,top:0,height:240,width:639,url:"https://mkt.naver.com/p1/atrb?channel_id=naver_pcspeciallogo&campaign_id=2311-logo-001&target=https%3A%2F%2Fnaver.me%2FxguXFZwP%3Fdtm_source%3Dnaver_pcspeciallogo%26dtm_medium%3Dmktatrb_mn%26dtm_campaign%3D2311-logo-001",alt:"생일 축하 합니다.",clickCode:"top.hbdlogo"}],isBirthday:!0}),{content:t}}if(o)return{content:o};var t=Math.floor(Math.random()*i.items.length);return i.items[t]}();i.items=[s];const a=s&&s.content?s.content.input:null;t(a&&a.color);const n=document.getElementById("search"),c=n&&(!a||!a.showSearchLogo);c&&n.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",function(){var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?c&&n.classList.remove("type_special_logo_full"):c&&n.classList.add("type_special_logo_full")});var l=a&&a.placeholder;if(l){var r=document.getElementById("query");r&&l&&r.setAttribute("title",l),r&&l&&r.setAttribute("placeholder",l)}}()</script> </body> </html>
